# %%
# Machine Learning
# Types of Machine Learning
# Supervised, Unsupervised and Reinforcement learning

# %%
# 1. Data preprocessing
# Data cleaning
# steps
"""_summary_
1. duplicates
2. wrong format
3. wrong data
4. empty cells / missing data
"""
# Age 23,  230
# wrong format, 1/7/2024, 2/7/2024, 372024
# handling missing data, remove/delete, Imputation, mean/median/mode, Use forward/backward filling, kNN or Regression
# Out:
# '_summary_\n1. duplicates\n2. wrong format\n3. wrong data\n4. empty cells / missing data\n'

# %%
# 3. Exploratory Data Analysis (EDA)
# steps
"""_summary_
1. descriptive statistics:
   measure of central tendancy, mean, median, mode
2. measure of spread:
   range, variance, standard deviation, interquartile range
3. skewness, kurtosis
4. Data visualization
   Histogram - distribution of a single variable,
   Boxplot - identifying outliers,
   scatter plot - examine relationships between two variables
   Heatmaps - visualizing correlation matrics       
"""
# Out:
# '_summary_\n1. descriptive statistics:\n   measure of central tendancy, mean, median, mode\n2. measure of spread:\n   range, variance, standard deviation, interquartile range\n3. skewness, kurtosis\n4. Data visualization\n   Histogram - distribution of a single variable,\n   Boxplot - identifying outliers,\n   scatter plot - examine relationships between two variables\n   Heatmaps - visualizing correlation matrics       \n'

# %%
# Tools for data visualization
# Matplotlib - line, bar, scatter graph and histogram.
# Seaborn - themes, color palettes, looks more attractive
# Plotly, Bokeh

# %%
# Feature Engineering
# Selection, filter like chi-square, ANOVA
# Wrapper recursive features 
# Embedded, Lasso regression
# 
# // Feature scaling and normalization 
# Normalization Rescale to a range, (Age, 20-28)
# Standard deviation, transform std

# create new features, polynomals, interaction

# %%
# Data splitting
# Training and evaluation of a model
# Most common rations, 20testing - 80training, 30, 70
# import Scikit-learn help to split train_test_split

# Random state is used to shuffle data before splitting it into a training and test set.

# %%
# Cross validation
# Is to evaluate the performance of the data, mulple folds
# Types are : train/test we can use K-Fold cross validation
# Stratified K-fold - ensure our distribution of the target variable, particulary used in the imbalance dataset
# Cross validation helps in reducing variation in model performance estimates
# provide comprehence evaluation of model performance

# %%
# Supervised Learning algorithms
# Regression - Linear or Polynomial
# Classification - Logistic regression, KNN, Support Vector Machine, Decision trees, and Random forest

# %%
# Model Evaluation
# Metrics: Accuracy, Precision, Recall, F1-score
# Confusion Matrix
# AUC and ROC - Area Under the Curve, Receiver Operating Characteristics Curve

# %%
"""_summary_
1. Supervised learning
   Labeled data, predict output for new inputs, common tasks, Classification and Regresion

2. Unsupervised learning
   Unlabelled data, find hidden patterns or structures in data, common tasks like, clustering, dimensionality,
   association Rule learning

Definition 
Supervised learning : learns from labeled data to predict output and outputs for new inputs 
Unsupervised learning learns from unlabeled data to identify patterns in structures within data       
"""
# Out:
# '_summary_\n1. Supervised learning\n   Labeled data, predict output for new inputs, common tasks, Classification and Regresion\n\n2. Unsupervised learning\n   Unlabelled data, find hidden patterns or structures in data, common tasks like, clustering, dimensionality,\n   association Rule learning\n\nDefinition \nSupervised learning : learns from labeled data to predict output and outputs for new inputs \nUnsupervised learning learns from unlabeled data to identify patterns in structures within data       \n'

# %%
# import necessary libraries
import pandas as pd

# Load the data set
df = pd.read_csv("heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Preprocessing / Data cleaning
# 1. Empty cells or missing data
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 2. Duplicates
# Finding and displaying all duplicated rows(considering all columns)
duplicated_rows = df[df.duplicated(keep=False)] # 'keep=False' returns how many times that row appears
print("Duplicated rows across the dataframe")
print(duplicated_rows)
# Out:
# Duplicated rows across the dataframe
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 163      2   4     2       1
# 164      2   4     2       1

# %%
# dropping one of the duplicated row
df = df.drop_duplicates()
# Checking for duplicates
remaining_duplicates = df[df.duplicated(keep=False)]
print("Remaining duplicates:")
print(remaining_duplicates)
# Out:
# Remaining duplicates:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
# 3. Wrong format
# checking for data formats for all columns
print(df.dtypes)
df.info()
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
# ...

# %%
# checking numeric columns for wrong data format
numeric_cols = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    inconsistent_count = df[col].isna().sum()
    print(f"Inconsistent numeric value : {inconsistent_count}")
# Out:
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# Inconsistent numeric value : 0
# /tmp/ipykernel_4326/3049854460.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# 4. Wrong data
# Visualize wrong data using boxplot to spot outliers
import matplotlib.pylab as plt

plt.figure(figsize=(12,8))
df.boxplot(column=numeric_cols)
plt.title("Box plot for numeric columns")
plt.show()

# %%
# Define a function to Identifying outliers in each column using IQR
def identify_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# %%
# Identify outliers in each nmeric column
for columns in numeric_cols:
    outliers = identify_outliers(df, columns)
    print(f"Outliers in {columns}")
    print(outliers)
# Out:
# Outliers in age
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []
# Outliers in sex
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []
# Outliers in cp
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []
# Outliers in trestbps
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     52    1   2       172   199    1        1      162      0      0.5
# 101   59    1   3       178   270    0        0      145      0      4.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 203   68    1   2       180   274    1        0      150      1      1.6
# 223   56    0   0       200   288    1        0      133      1      4.0
# ...

# %%
# Drop outliers from each numeric column
#for columns in numeric_cols:
#    Q1 = df[columns].quantile(0.25)
#    Q3 = df[columns].quantile(0.75)
#    IQR = Q3 - Q1
#    lower_bound = Q1 - 1.5 * IQR
#    upper_bound = Q3 + 1.5 * IQR
#    df = df[(df[columns] >= lower_bound) & (df[columns] <= upper_bound)]

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Re-assigning indexes
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Exporting a clean dataset
df.to_csv('cleaned_heart.csv', index=False)

# %%
# EDA (Exploratory Data Analysis)
#1. descriptive statistics:
#   measure of central tendancy, mean, median, mode

import pandas as pd
df = pd.read_csv("cleaned_heart.csv")
# Get descriptive statistics (mean, median, mode)

desc_stats = df.describe()
# selecting mean and median 
summary = desc_stats.T[['mean','50%']]
print(summary)
# Out:
#                 mean    50%
# age        54.420530   55.5
# sex         0.682119    1.0
# cp          0.963576    1.0
# trestbps  131.602649  130.0
# chol      246.500000  240.5
# fbs         0.149007    0.0
# restecg     0.526490    1.0
# thalach   149.569536  152.5
# exang       0.327815    0.0
# oldpeak     1.043046    0.8
# slope       1.397351    1.0
# ca          0.718543    0.0
# thal        2.314570    2.0
# target      0.543046    1.0

# %%
# get mode for each column
modes = df.mode().iloc[0]
print("Mode value")
print(modes)
# Out:
# Mode value
# age          58.0
# sex           1.0
# cp            0.0
# trestbps    120.0
# chol        197.0
# fbs           0.0
# restecg       1.0
# thalach     162.0
# exang         0.0
# oldpeak       0.0
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 0, dtype: float64

# %%
# 2. measure of spread:
#   range, variance, standard deviation, interquartile range

# calculate range
range_df = df.max() - df.min() 

# calculate variance
variance_df = df.var()

# calculate standard deviation
std_dev_df = df.std()

# calculate the interquatile range
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR_df = q3 - q1

# %%
# summary data frame
spread_summary = pd.DataFrame({
    'Range': range_df,
    'Variance' : variance_df,
    'Standard Deviation' : std_dev_df,
    'Interquatile Range' : IQR_df
})
print(spread_summary)
# Out:
#           Range     Variance  Standard Deviation  Interquatile Range
# age        48.0    81.865757            9.047970               13.00
# sex         1.0     0.217553            0.466426                1.00
# cp          3.0     1.065114            1.032044                2.00
# trestbps  106.0   308.472817           17.563394               20.00
# chol      438.0  2678.423588           51.753489               63.75
# fbs         1.0     0.127225            0.356686                0.00
# restecg     2.0     0.276705            0.526027                1.00
# thalach   131.0   524.571561           22.903527               32.75
# exang       1.0     0.221084            0.470196                1.00
# oldpeak     6.2     1.348971            1.161452                1.60
# slope       2.0     0.379794            0.616274                1.00
# ca          4.0     1.013542            1.006748                1.00
# thal        3.0     0.375800            0.613026                1.00
# ...

# %%
# 3. skewness, kurtosis
# Calculate skewness and kurtosis for each column
from scipy.stats import skew, kurtosis
skewness_df = df.apply(lambda x: skew(x.dropna()))
kurtosis_df = df.apply(lambda x: kurtosis(x.dropna(), fisher=False)) # fisher=False gives Pearson's definition (3 for normal distribution)

# %%
# shape summary
shape_summary = pd.DataFrame({
    'Skewness' : skewness_df,
    'Kurtosis' : kurtosis_df
 })
print(shape_summary)
# Out:
#           Skewness  Kurtosis
# age      -0.202730  2.461379
# sex      -0.782210  1.611853
# cp        0.490569  1.815976
# trestbps  0.712978  3.887984
# chol      1.141626  7.447929
# fbs       1.971347  4.886208
# restecg   0.168624  1.643138
# thalach  -0.530022  2.919037
# exang     0.733614  1.538190
# oldpeak   1.259875  4.522236
# slope    -0.500744  2.360644
# ca        1.289294  3.748331
# thal     -0.478839  3.271177
# target   -0.172827  1.029869

# %%
# 4. Data visualization
# 1. Histogram
plt.figure(figsize=(10, 6))
df['age'].hist(bins=10, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['cp'].hist(bins=10, edgecolor='black')
plt.title('cp Distribution')
plt.xlabel('cp')
plt.ylabel('Frequency')
plt.show()

# %%
df['trestbps'].hist(bins=10, edgecolor='black')
plt.title('trestbps Distribution')
plt.xlabel('trestbps')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Boxplot
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['age', 'trestbps', 'chol']])
plt.title('Boxplot of Age, Resting Blood Pressure, and Cholesterol')
plt.show()

# %%
# 3. Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='chol', data=df, hue='sex', palette='viridis')
plt.title('Scatter Plot of Age vs Cholesterol')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.legend(title='Sex', loc='upper left', labels=['Male', 'Female'])
plt.show()

# %%
# 4. Heatmap
plt.figure(figsize=(10, 6))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()
